# %% [markdown]
# <a href="https://colab.research.google.com/github/simasaadi/canada-climate-80yrs/blob/main/01_data_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01 — Data Audit (Canadian Climate Daily)
#
# Goal: validate data structure, date coverage, station coverage, missingness, and basic sanity checks.

# %%
# 1) fresh clone
# !rm -rf canada-climate-80yrs
# !git clone https://github.com/simasaadi/canada-climate-80yrs.git

# 2) inspect repo structure
# !ls -la canada-climate-80yrs
print("\n--- notebooks path check ---")
# !ls -la canada-climate-80yrs/notebooks || true
# Out:
# Cloning into 'canada-climate-80yrs'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 32 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 973.09 KiB | 2.51 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# total 44
# drwxr-xr-x 5 root root 4096 Dec 12 18:36 .
# drwxr-xr-x 1 root root 4096 Dec 12 18:36 ..
# -rw-r--r-- 1 root root  922 Dec 12 18:36 01_data_audit.ipynb
# -rw-r--r-- 1 root root    1 Dec 12 18:36 app.py
# drwxr-xr-x 3 root root 4096 Dec 12 18:36 data
# drwxr-xr-x 2 root root 4096 Dec 12 18:36 docs
# drwxr-xr-x 8 root root 4096 Dec 12 18:36 .git
# -rw-r--r-- 1 root root    1 Dec 12 18:36 .gitignore
# -rw-r--r-- 1 root root    1 Dec 12 18:36 notebooks
# -rw-r--r-- 1 root root   22 Dec 12 18:36 README.md
# -rw-r--r-- 1 root root    1 Dec 12 18:36 requirements.txt
#
# --- notebooks path check ---
# ...
