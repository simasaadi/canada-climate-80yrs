# %% [markdown]
# <a href="https://colab.research.google.com/github/simasaadi/canada-climate-80yrs/blob/main/notebooks/01_data_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01 — Data Audit (Canadian Climate Daily)
#
# Goal: validate data structure, date coverage, station coverage, missingness, and basic sanity checks.

# %%
# 1) fresh clone
# !rm -rf canada-climate-80yrs
# !git clone https://github.com/simasaadi/canada-climate-80yrs.git

# 2) inspect repo structure
# !ls -la canada-climate-80yrs
print("\n--- notebooks path check ---")
# !ls -la canada-climate-80yrs/notebooks || true
# Out:
# Cloning into 'canada-climate-80yrs'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 32 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 973.09 KiB | 2.51 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# total 44
# drwxr-xr-x 5 root root 4096 Dec 12 18:36 .
# drwxr-xr-x 1 root root 4096 Dec 12 18:36 ..
# -rw-r--r-- 1 root root  922 Dec 12 18:36 01_data_audit.ipynb
# -rw-r--r-- 1 root root    1 Dec 12 18:36 app.py
# drwxr-xr-x 3 root root 4096 Dec 12 18:36 data
# drwxr-xr-x 2 root root 4096 Dec 12 18:36 docs
# drwxr-xr-x 8 root root 4096 Dec 12 18:36 .git
# -rw-r--r-- 1 root root    1 Dec 12 18:36 .gitignore
# -rw-r--r-- 1 root root    1 Dec 12 18:36 notebooks
# -rw-r--r-- 1 root root   22 Dec 12 18:36 README.md
# -rw-r--r-- 1 root root    1 Dec 12 18:36 requirements.txt
#
# --- notebooks path check ---
# ...

# %%
import pandas as pd
import numpy as np

from pathlib import Path
import matplotlib.pyplot as plt

DATA_PATH = Path("../data/raw/canadian_climate_daily.csv")  # <-- must match your uploaded filename
FIG_DIR = Path("../reports/figures")
FIG_DIR.mkdir(parents=True, exist_ok=True)

print("DATA_PATH exists?", DATA_PATH.exists(), "|", DATA_PATH)
# Out:
# DATA_PATH exists? False | ../data/raw/canadian_climate_daily.csv

# %%
# !rm -rf /content/canada-climate-80yrs
# !git clone https://github.com/simasaadi/canada-climate-80yrs.git
# !find /content/canada-climate-80yrs -maxdepth 2 -type f -name "notebooks" -print
# !ls -la /content/canada-climate-80yrs
# !ls -la /content/canada-climate-80yrs/notebooks
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'canada-climate-80yrs': No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# find: ‘/content/canada-climate-80yrs’: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ls: cannot access '/content/canada-climate-80yrs': No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ls: cannot access '/content/canada-climate-80yrs/notebooks': No such file or directory

# %%
import os
os.chdir("/content")
print("Now in:", os.getcwd())
# Out:
# Now in: /content

# %%
# !rm -rf /content/canada-climate-80yrs
# !git clone https://github.com/simasaadi/canada-climate-80yrs.git

# verify structure
# !ls -la /content/canada-climate-80yrs
# !ls -la /content/canada-climate-80yrs/notebooks
# !ls -la /content/canada-climate-80yrs/data/raw
# Out:
# Cloning into 'canada-climate-80yrs'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 52 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 979.11 KiB | 2.33 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# total 40
# drwxr-xr-x 6 root root 4096 Dec 12 18:56 .
# drwxr-xr-x 1 root root 4096 Dec 12 18:56 ..
# -rw-r--r-- 1 root root    1 Dec 12 18:56 app.py
# drwxr-xr-x 3 root root 4096 Dec 12 18:56 data
# drwxr-xr-x 2 root root 4096 Dec 12 18:56 docs
# drwxr-xr-x 8 root root 4096 Dec 12 18:56 .git
# -rw-r--r-- 1 root root    1 Dec 12 18:56 .gitignore
# drwxr-xr-x 2 root root 4096 Dec 12 18:56 notebooks
# -rw-r--r-- 1 root root   22 Dec 12 18:56 README.md
# -rw-r--r-- 1 root root    1 Dec 12 18:56 requirements.txt
# total 20
# drwxr-xr-x 2 root root 4096 Dec 12 18:56 .
# drwxr-xr-x 6 root root 4096 Dec 12 18:56 ..
# ...
