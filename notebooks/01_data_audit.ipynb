# %% [markdown]
# <a href="https://colab.research.google.com/github/simasaadi/canada-climate-80yrs/blob/main/notebooks/01_data_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01 — Data Audit (Canadian Climate Daily)
#
# Goal: validate data structure, date coverage, station coverage, missingness, and basic sanity checks.

# %%
# --- Standard setup for Colab (stable + self-healing) ---

import os
from pathlib import Path

REPO_NAME = "canada-climate-80yrs"
REPO_URL = "https://github.com/simasaadi/canada-climate-80yrs.git"

repo_path = Path(REPO_NAME)
notebooks_path = repo_path / "notebooks"

# If repo exists but notebooks is not a directory, it's an old/bad clone -> re-clone
if repo_path.exists() and (not notebooks_path.exists() or not notebooks_path.is_dir()):
    print("Found an old/broken clone. Removing and re-cloning...")
    # !rm -rf "{REPO_NAME}"

# Clone if missing
if not repo_path.exists():
    # !git clone "{REPO_URL}"

# Move into notebooks
os.chdir(notebooks_path)
print("Working directory:", os.getcwd())

# Quick proof
print("notebooks is_dir:", Path(".").resolve().is_dir())
# Out:
# Cloning into 'canada-climate-80yrs'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 43 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 976.80 KiB | 2.29 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# Working directory: /content/canada-climate-80yrs/notebooks
# notebooks is_dir: True

# %%
import pandas as pd
import numpy as np

from pathlib import Path
import matplotlib.pyplot as plt

DATA_PATH = Path("../data/raw/canadian_climate_daily.csv")  # <-- must match your uploaded filename
FIG_DIR = Path("../reports/figures")
FIG_DIR.mkdir(parents=True, exist_ok=True)

print("DATA_PATH exists?", DATA_PATH.exists(), "|", DATA_PATH)
# Out:
# DATA_PATH exists? False | ../data/raw/canadian_climate_daily.csv
