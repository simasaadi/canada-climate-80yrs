# %% [markdown]
# <a href="https://colab.research.google.com/github/simasaadi/canada-climate-80yrs/blob/main/02_data_cleaning_reshaping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import re

REPO_DIR = Path("/content/canada-climate-80yrs")
RAW_PATH = REPO_DIR / "data" / "raw" / "canadian_climate_daily.csv"
PROCESSED_DIR = REPO_DIR / "data" / "processed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print("RAW exists:", RAW_PATH.exists(), "|", RAW_PATH)
print("Processed dir:", PROCESSED_DIR)
# Out:
# RAW exists: False | /content/canada-climate-80yrs/data/raw/canadian_climate_daily.csv
# Processed dir: /content/canada-climate-80yrs/data/processed

# %%
from pathlib import Path
import os

REPO_NAME = "canada-climate-80yrs"
REPO_URL  = "https://github.com/simasaadi/canada-climate-80yrs.git"
REPO_DIR  = Path("/content") / REPO_NAME

# Ensure we are in /content (prevents weird cwd issues)
os.chdir("/content")

# Clone only if missing
if not REPO_DIR.exists():
    # !git clone {REPO_URL}

RAW_PATH = REPO_DIR / "data" / "raw" / "canadian_climate_daily.csv"
PROCESSED_DIR = REPO_DIR / "data" / "processed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print("Repo dir exists:", REPO_DIR.exists(), REPO_DIR)
print("RAW exists:", RAW_PATH.exists(), RAW_PATH)

# Show what's inside data/raw (removes doubt)
print("\nFiles in data/raw:")
for p in sorted((REPO_DIR / "data" / "raw").glob("*")):
    print(" -", p.name, "|", p.stat().st_size, "bytes")
# Out:
# Repo dir exists: True /content/canada-climate-80yrs
# RAW exists: False /content/canada-climate-80yrs/data/raw/canadian_climate_daily.csv
#
# Files in data/raw:

# %%
import pandas as pd

df = pd.read_csv(RAW_PATH)
df["LOCAL_DATE"] = pd.to_datetime(df["LOCAL_DATE"], errors="coerce")

assert df["LOCAL_DATE"].isna().sum() == 0, "LOCAL_DATE parsing failed for some rows"

print("Shape:", df.shape)
print("Date range:", df["LOCAL_DATE"].min(), "→", df["LOCAL_DATE"].max())
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1313249677.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv(RAW_PATH)
#       4 df["LOCAL_DATE"] = pd.to_datetime(df["LOCAL_DATE"], errors="coerce")
#       5
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/canada-climate-80yrs/data/raw/canadian_climate_daily.csv'
